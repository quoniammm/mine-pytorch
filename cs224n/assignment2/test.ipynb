# %%
import tensorflow as tf
# Out:
# /home/quoniammm/anaconda3/envs/py3Tfgpu/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# ?tf.expand_dims

# %%
# ?tf.reduce_sum

# %%
# ?tf.reduce_max

# %%
max = tf.constant([[1, 2, 3], [2, 3, 4]])
max
# Out:
# <tf.Tensor 'Const_4:0' shape=(2, 3) dtype=int32>

# %%
a = tf.reduce_max(max, 1)
sess = tf.InteractiveSession()
a = tf.expand_dims(a, 1)
a
# Out:
# <tf.Tensor 'ExpandDims_2:0' shape=(2, 1) dtype=int32>

# %%
b = tf.exp(a)
b.eval()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d7d1c5403936> in <module>()
# ----> 1 b = tf.exp(a, type=float)
#       2 b.eval()
#
# TypeError: exp() got an unexpected keyword argument 'type'

# %%
# ?tf.to_float

# %%
# ?tf.random_uniform

# %%
a = [1,2,3]

# %%
b = a[:]

# %%
b
# Out:
# [1, 2, 3]

# %%
c = a

# %%
b[0] = 3
b
# Out:
# [3, 2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %%
c[0] = 3

# %%
c
# Out:
# [3, 2, 3]

# %%
import tensorflow as tf
# Out:
# /home/quoniammm/anaconda3/envs/py3Tfgpu/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
t = [
    [True, False, False],
    [False, False, True],
    [False, True, False]
]

# %%
sess = tf.InteractiveSession()
a = tf.zeros_like(t)
a.shape
b = tf.ones_like(t)
b.shape
b.eval()
b.get_shape()
b.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7e323184276c> in <module>()
#       6 b.eval()
#       7 b.get_shape()
# ----> 8 b.shape()
#
# TypeError: 'TensorShape' object is not callable
