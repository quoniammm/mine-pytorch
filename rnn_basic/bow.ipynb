# %% [markdown]
# ## Bag of Words (BOW) 实现

# %%
from collections import defaultdict # 为字典元素赋初始值
import time
import random
import dynet as dy
import numpy as np

# %%
# 数据初始化
w2i = defaultdict(lambda: len(w2i))
t2i = defaultdict(lambda: len(t2i))
UNK = w2i["<unk>"]
def read_dataset(filename):
    with open(filename, "r") as f:
        for line in f:
            tag, words = line.lower().strip().split(" ||| ")
            yield ([w2i[x] for x in words.split(" ")], t2i[tag])

# %%
train = list(read_dataset("data/classes/train.txt"))
w2i = defaultdict(lambda: UNK, w2i)
dev = list(read_dataset("data/classes/test.txt"))
nwords = len(w2i)
ntags = len(t2i)

# %%
# 定义模型和参数
model = dy.Model()
trainer = dy.AdamTrainer(model)

# %%
W_sm = model.add_lookup_parameters((nwords, ntags))
b_sm = model.add_parameters((ntags))

# %%
def calc_scores(words):
    dy.renew_cg()
    b_sm_exp = dy.parameter(b_sm)
    score = dy.esum([dy.lookup(W_sm, x) for x in words])
    
    return score + b_sm_exp

# %%
for ITER in range(100):
    # 训练集表现
    random.shuffle(train)
    train_loss = 0.0
    start = time.time()
    for words, tag in train:
        my_loss = dy.pickneglogsoftmax(calc_scores(words), tag)
        train_loss += my_loss.value()
        my_loss.backward()
        trainer.update()
    print("iter %s: train loss=%.4f, time=%.2fs" % (ITER, train_loss/len(train), time.time()-start))
    # 测试集表现
    test_correct = 0.0
    for wirds, tag in dev:
        scores = calc_scores(words).npvalue()
        predict = np.argmax(scores)
        if predict == tag:
            test_correct += 1
    print("iter %s: test acc=%.4f" %(ITER, test_correct/len(dev)))
# Out:
# iter 0: train loss=2.4340, time=0.23s
# iter 0: test acc=0.2864
# iter 1: train loss=2.0407, time=0.24s
# iter 1: test acc=0.2308
# iter 2: train loss=1.8487, time=0.24s
# iter 2: test acc=0.2864
# iter 3: train loss=1.7146, time=0.24s
# iter 3: test acc=0.1262
# iter 4: train loss=1.6076, time=0.23s
# iter 4: test acc=0.1760
# iter 5: train loss=1.5172, time=0.23s
# iter 5: test acc=0.1760
# iter 6: train loss=1.4414, time=0.24s
# iter 6: test acc=0.1760
# iter 7: train loss=1.3737, time=0.26s
# iter 7: test acc=0.1760
# iter 8: train loss=1.3132, time=0.26s
# iter 8: test acc=0.2864
# iter 9: train loss=1.2596, time=0.27s
# iter 9: test acc=0.1805
# iter 10: train loss=1.2098, time=0.25s
# iter 10: test acc=0.2308
# iter 11: train loss=1.1656, time=0.23s
# iter 11: test acc=0.1262
# iter 12: train loss=1.1247, time=0.24s
# iter 12: test acc=0.2864
# iter 13: train loss=1.0869, time=0.28s
# iter 13: test acc=0.1805
# iter 14: train loss=1.0516, time=0.23s
# iter 14: test acc=0.2864
# iter 15: train loss=1.0190, time=0.24s
# iter 15: test acc=0.2308
# iter 16: train loss=0.9891, time=0.22s
# iter 16: test acc=0.1805
# iter 17: train loss=0.9609, time=0.23s
# iter 17: test acc=0.2864
# iter 18: train loss=0.9346, time=0.23s
# iter 18: test acc=0.1805
# iter 19: train loss=0.9097, time=0.27s
# iter 19: test acc=0.2308
# iter 20: train loss=0.8861, time=0.26s
# iter 20: test acc=0.2308
# iter 21: train loss=0.8638, time=0.24s
# iter 21: test acc=0.2308
# iter 22: train loss=0.8434, time=0.27s
# iter 22: test acc=0.2308
# iter 23: train loss=0.8238, time=0.26s
# iter 23: test acc=0.2864
# iter 24: train loss=0.8051, time=0.24s
# iter 24: test acc=0.2308
# iter 25: train loss=0.7878, time=0.25s
# iter 25: test acc=0.2864
# iter 26: train loss=0.7707, time=0.26s
# iter 26: test acc=0.2308
# iter 27: train loss=0.7545, time=0.26s
# iter 27: test acc=0.1760
# iter 28: train loss=0.7399, time=0.27s
# iter 28: test acc=0.2864
# iter 29: train loss=0.7254, time=0.25s
# iter 29: test acc=0.2308
# iter 30: train loss=0.7113, time=0.25s
# iter 30: test acc=0.1760
# iter 31: train loss=0.6982, time=0.25s
# iter 31: test acc=0.2864
# iter 32: train loss=0.6855, time=0.24s
# iter 32: test acc=0.2308
# iter 33: train loss=0.6737, time=0.28s
# iter 33: test acc=0.2864
# iter 34: train loss=0.6619, time=0.24s
# iter 34: test acc=0.1805
# iter 35: train loss=0.6513, time=0.26s
# iter 35: test acc=0.1805
# iter 36: train loss=0.6405, time=0.28s
# iter 36: test acc=0.2308
# iter 37: train loss=0.6301, time=0.27s
# iter 37: test acc=0.1262
# iter 38: train loss=0.6204, time=0.28s
# iter 38: test acc=0.1805
# iter 39: train loss=0.6112, time=0.29s
# iter 39: test acc=0.2864
# iter 40: train loss=0.6022, time=0.24s
# iter 40: test acc=0.2864
# iter 41: train loss=0.5928, time=0.24s
# iter 41: test acc=0.1805
# iter 42: train loss=0.5843, time=0.24s
# iter 42: test acc=0.1760
# iter 43: train loss=0.5765, time=0.23s
# iter 43: test acc=0.1262
# iter 44: train loss=0.5682, time=0.23s
# iter 44: test acc=0.1760
# iter 45: train loss=0.5609, time=0.23s
# iter 45: test acc=0.2308
# iter 46: train loss=0.5536, time=0.23s
# iter 46: test acc=0.2308
# iter 47: train loss=0.5462, time=0.23s
# iter 47: test acc=0.2308
# iter 48: train loss=0.5394, time=0.23s
# iter 48: test acc=0.2308
# iter 49: train loss=0.5328, time=0.22s
# iter 49: test acc=0.2308
# iter 50: train loss=0.5262, time=0.23s
# iter 50: test acc=0.2864
# iter 51: train loss=0.5200, time=0.23s
# iter 51: test acc=0.2308
# iter 52: train loss=0.5140, time=0.24s
# iter 52: test acc=0.1760
# iter 53: train loss=0.5082, time=0.26s
# iter 53: test acc=0.1805
# iter 54: train loss=0.5019, time=0.27s
# iter 54: test acc=0.2864
# iter 55: train loss=0.4967, time=0.23s
# iter 55: test acc=0.1805
# iter 56: train loss=0.4910, time=0.28s
# iter 56: test acc=0.2864
# iter 57: train loss=0.4862, time=0.25s
# iter 57: test acc=0.2864
# iter 58: train loss=0.4806, time=0.24s
# iter 58: test acc=0.1805
# iter 59: train loss=0.4757, time=0.24s
# iter 59: test acc=0.2864
# iter 60: train loss=0.4710, time=0.24s
# iter 60: test acc=0.2308
# iter 61: train loss=0.4662, time=0.25s
# iter 61: test acc=0.2308
# iter 62: train loss=0.4606, time=0.23s
# iter 62: test acc=0.2308
# iter 63: train loss=0.4564, time=0.23s
# iter 63: test acc=0.1262
# iter 64: train loss=0.4520, time=0.24s
# iter 64: test acc=0.1262
# iter 65: train loss=0.4478, time=0.23s
# iter 65: test acc=0.1805
# iter 66: train loss=0.4436, time=0.22s
# iter 66: test acc=0.2308
# iter 67: train loss=0.4396, time=0.23s
# iter 67: test acc=0.2864
# iter 68: train loss=0.4353, time=0.24s
# iter 68: test acc=0.1805
# iter 69: train loss=0.4312, time=0.25s
# iter 69: test acc=0.1262
# iter 70: train loss=0.4272, time=0.25s
# iter 70: test acc=0.2308
# iter 71: train loss=0.4235, time=0.25s
# iter 71: test acc=0.1760
# iter 72: train loss=0.4200, time=0.25s
# iter 72: test acc=0.1262
# iter 73: train loss=0.4164, time=0.28s
# iter 73: test acc=0.2308
# iter 74: train loss=0.4125, time=0.27s
# iter 74: test acc=0.2864
# iter 75: train loss=0.4091, time=0.27s
# iter 75: test acc=0.2864
# iter 76: train loss=0.4057, time=0.26s
# iter 76: test acc=0.1760
# iter 77: train loss=0.4023, time=0.26s
# iter 77: test acc=0.1760
# iter 78: train loss=0.3987, time=0.26s
# iter 78: test acc=0.1760
# iter 79: train loss=0.3958, time=0.25s
# iter 79: test acc=0.1262
# iter 80: train loss=0.3925, time=0.25s
# iter 80: test acc=0.2864
# iter 81: train loss=0.3896, time=0.27s
# iter 81: test acc=0.2308
# iter 82: train loss=0.3863, time=0.27s
# iter 82: test acc=0.2864
# iter 83: train loss=0.3835, time=0.27s
# iter 83: test acc=0.1262
# iter 84: train loss=0.3807, time=0.27s
# iter 84: test acc=0.1262
# iter 85: train loss=0.3778, time=0.26s
# iter 85: test acc=0.2864
# iter 86: train loss=0.3748, time=0.25s
# iter 86: test acc=0.2864
# iter 87: train loss=0.3719, time=0.26s
# iter 87: test acc=0.1262
# iter 88: train loss=0.3692, time=0.25s
# iter 88: test acc=0.1805
# iter 89: train loss=0.3664, time=0.26s
# iter 89: test acc=0.1760
# iter 90: train loss=0.3638, time=0.26s
# iter 90: test acc=0.1805
# iter 91: train loss=0.3613, time=0.24s
# iter 91: test acc=0.2308
# iter 92: train loss=0.3584, time=0.25s
# iter 92: test acc=0.2864
# iter 93: train loss=0.3561, time=0.25s
# iter 93: test acc=0.2308
# iter 94: train loss=0.3536, time=0.25s
# iter 94: test acc=0.1262
# iter 95: train loss=0.3511, time=0.24s
# iter 95: test acc=0.1805
# iter 96: train loss=0.3485, time=0.25s
# iter 96: test acc=0.1760
# iter 97: train loss=0.3465, time=0.24s
# iter 97: test acc=0.1760
# iter 98: train loss=0.3440, time=0.24s
# iter 98: test acc=0.2308
# iter 99: train loss=0.3419, time=0.25s
# iter 99: test acc=0.1805
