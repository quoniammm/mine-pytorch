# %% [markdown]
# # Improved LSTM baseline
#
# This kernel is a somewhat improved version of [Keras - Bidirectional LSTM baseline](https://www.kaggle.com/CVxTz/keras-bidirectional-lstm-baseline-lb-0-051) along with some additional documentation of the steps.

# %%
import sys, os, re, csv, codecs, numpy as np, pandas as pd

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers
# Out:
# Using TensorFlow backend.
# /home/quoniammm/anaconda3/envs/py3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# We include the GloVe word vectors in our input files. To include these in your kernel, simple click 'input files' at the top of the notebook, and search 'glove' in the 'datasets' section.

# %%
path = './'
comp = ''
EMBEDDING_FILE=f'{path}glove6b/glove.6B.50d.txt'
TRAIN_DATA_FILE=f'{path}{comp}train.csv'
TEST_DATA_FILE=f'{path}{comp}test.csv'

# %% [markdown]
# Set some basic config parameters:

# %%
embed_size = 50 # how big is each word vector
max_features = 15000 # how many unique words to use (i.e num rows in embedding vector)
maxlen = 30 # max number of words in a comment to use

# %% [markdown]
# Read in our data and replace missing values:

# %%
train = pd.read_csv(TRAIN_DATA_FILE)
test = pd.read_csv(TEST_DATA_FILE)

list_sentences_train = train["comment_text"].fillna("_na_").values
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
y = train[list_classes].values
list_sentences_test = test["comment_text"].fillna("_na_").values

# %%
#list_sentences_train[:5]
#y[:5]

# %% [markdown]
# Standard keras preprocessing, to turn each comment into a list of word indexes of equal length (with truncation or padding as needed).

# %%
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(list_sentences_train))
list_tokenized_train = tokenizer.texts_to_sequences(list_sentences_train)
list_tokenized_test = tokenizer.texts_to_sequences(list_sentences_test)
X_t = pad_sequences(list_tokenized_train, maxlen=maxlen)
X_te = pad_sequences(list_tokenized_test, maxlen=maxlen)

# %% [markdown]
# Read the glove word vectors (space delimited strings) into a dictionary from word->vector.

# %%
# X_t[:5]

# %%
def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(EMBEDDING_FILE))

# %% [markdown]
# Use these vectors to create our embedding matrix, with random initialization for words that aren't in GloVe. We'll use the same mean and stdev of embeddings the GloVe has when generating the random init.

# %%
all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
emb_mean,emb_std
# Out:
# (0.020940498, 0.6441043)

# %%
all_embs[:5]
# Out:
# array([[  4.18000013e-01,   2.49679998e-01,  -4.12420005e-01,
#           1.21699996e-01,   3.45270008e-01,  -4.44569997e-02,
#          -4.96879995e-01,  -1.78619996e-01,  -6.60229998e-04,
#          -6.56599998e-01,   2.78430015e-01,  -1.47670001e-01,
#          -5.56770027e-01,   1.46579996e-01,  -9.50950012e-03,
#           1.16579998e-02,   1.02040000e-01,  -1.27920002e-01,
#          -8.44299972e-01,  -1.21809997e-01,  -1.68009996e-02,
#          -3.32789987e-01,  -1.55200005e-01,  -2.31309995e-01,
#          -1.91809997e-01,  -1.88230002e+00,  -7.67459989e-01,
#           9.90509987e-02,  -4.21249986e-01,  -1.95260003e-01,
#           4.00710011e+00,  -1.85939997e-01,  -5.22870004e-01,
#          -3.16810012e-01,   5.92130003e-04,   7.44489999e-03,
#           1.77780002e-01,  -1.58969998e-01,   1.20409997e-02,
#          -5.42230010e-02,  -2.98709989e-01,  -1.57490000e-01,
#          -3.47579986e-01,  -4.56370004e-02,  -4.42510009e-01,
#           1.87849998e-01,   2.78489990e-03,  -1.84110001e-01,
#          -1.15139998e-01,  -7.85809994e-01],
#        [  1.34410001e-02,   2.36819997e-01,  -1.68990001e-01,
#           4.09509987e-01,   6.38119996e-01,   4.77090001e-01,
#          -4.28519994e-01,  -5.56410015e-01,  -3.63999993e-01,
#          -2.39380002e-01,   1.30009994e-01,  -6.37340024e-02,
#          -3.95749986e-01,  -4.81620014e-01,   2.32910007e-01,
#           9.02009979e-02,  -1.33239999e-01,   7.86390007e-02,
#          -4.16339993e-01,  -1.54280007e-01,   1.00680001e-01,
#           4.88909990e-01,   3.12260002e-01,  -1.25200003e-01,
#          -3.75120007e-02,  -1.51789999e+00,   1.26120001e-01,
#          -2.44200006e-02,  -4.29610014e-02,  -2.83510000e-01,
#           3.54159999e+00,  -1.19560003e-01,  -1.45330001e-02,
#          -1.49900004e-01,   2.18640000e-01,  -3.34120005e-01,
#          -1.38720006e-01,   3.18060011e-01,   7.03580022e-01,
#           4.48579997e-01,  -8.02619979e-02,   6.30029976e-01,
#           3.21110010e-01,  -4.67649996e-01,   2.27860004e-01,
#           3.60339999e-01,  -3.78179997e-01,  -5.66569984e-01,
#           4.46910001e-02,   3.03920001e-01],
#        [  1.51639998e-01,   3.01770002e-01,  -1.67630002e-01,
#           1.76840007e-01,   3.17189991e-01,   3.39729995e-01,
#          -4.34780002e-01,  -3.10860008e-01,  -4.49990004e-01,
#          -2.94860005e-01,   1.66079998e-01,   1.19630001e-01,
#          -4.13280010e-01,  -4.23530012e-01,   5.98680019e-01,
#           2.88249999e-01,  -1.15470000e-01,  -4.18480001e-02,
#          -6.79889977e-01,  -2.50629991e-01,   1.84719995e-01,
#           8.68759975e-02,   4.65820014e-01,   1.50349997e-02,
#           4.34739999e-02,  -1.46710002e+00,  -3.03840011e-01,
#          -2.34409999e-02,   3.05889994e-01,  -2.17850000e-01,
#           3.74600005e+00,   4.22840007e-03,  -1.84359998e-01,
#          -4.62089986e-01,   9.83290002e-02,  -1.19070001e-01,
#           2.39189997e-01,   1.16099998e-01,   4.17050004e-01,
#           5.67630008e-02,  -6.36810000e-05,   6.89869970e-02,
#           8.79390016e-02,  -1.02849998e-01,  -1.39310002e-01,
#           2.23140001e-01,  -8.08029994e-02,  -3.56519997e-01,
#           1.64129995e-02,   1.02159999e-01],
#        [  7.08530009e-01,   5.70879996e-01,  -4.71599996e-01,
#           1.80480003e-01,   5.44489980e-01,   7.26029992e-01,
#           1.81569993e-01,  -5.23930013e-01,   1.03809997e-01,
#          -1.75659999e-01,   7.88519979e-02,  -3.62159997e-01,
#          -1.18290000e-01,  -8.33360016e-01,   1.19170003e-01,
#          -1.66050002e-01,   6.15549982e-02,  -1.27189998e-02,
#          -5.66229999e-01,   1.36160003e-02,   2.28510007e-01,
#          -1.43959999e-01,  -6.75489977e-02,  -3.81570011e-01,
#          -2.36980006e-01,  -1.70369995e+00,  -8.66919994e-01,
#          -2.67040014e-01,  -2.58899987e-01,   1.76699996e-01,
#           3.86759996e+00,  -1.61300004e-01,  -1.32730007e-01,
#          -6.88809991e-01,   1.84440002e-01,   5.24639990e-03,
#          -3.38739991e-01,  -7.89560005e-02,   2.41850004e-01,
#           3.65759999e-01,  -3.47270012e-01,   2.84830004e-01,
#           7.56929964e-02,  -6.21780008e-02,  -3.89880002e-01,
#           2.29020000e-01,  -2.16169998e-01,  -2.25620002e-01,
#          -9.39180031e-02,  -8.03749979e-01],
#        [  6.80469990e-01,  -3.92629988e-02,   3.01860005e-01,
#          -1.77919999e-01,   4.29619998e-01,   3.22460011e-02,
#          -4.13760006e-01,   1.32280007e-01,  -2.98469990e-01,
#          -8.52530003e-02,   1.71179995e-01,   2.24189997e-01,
#          -1.00460000e-01,  -4.36529994e-01,   3.34179997e-01,
#           6.78460002e-01,   5.72040007e-02,  -3.44480008e-01,
#          -4.27850008e-01,  -4.32749987e-01,   5.59629977e-01,
#           1.00319996e-01,   1.86770007e-01,  -2.68539995e-01,
#           3.73339988e-02,  -2.09319997e+00,   2.21709996e-01,
#          -3.98680001e-01,   2.09120005e-01,  -5.57250023e-01,
#           3.88260007e+00,   4.74660009e-01,  -9.56579983e-01,
#          -3.77880007e-01,   2.08690003e-01,  -3.27520013e-01,
#           1.27509996e-01,   8.83589983e-02,   1.63509995e-01,
#          -2.16340005e-01,  -9.43749994e-02,   1.83240008e-02,
#           2.10480005e-01,  -3.08800004e-02,  -1.97219998e-01,
#           8.22789967e-02,  -9.43399966e-02,  -7.32970014e-02,
#          -6.46990016e-02,  -2.60439992e-01]], dtype=float32)

# %%
word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

# %%
word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'of': 3,
#  'and': 4,
#  'a': 5,
#  'you': 6,
#  'i': 7,
#  'is': 8,
#  'that': 9,
#  'in': 10,
#  'it': 11,
#  'for': 12,
#  'this': 13,
#  'not': 14,
#  'on': 15,
#  'be': 16,
#  'as': 17,
#  'have': 18,
#  'are': 19,
#  'your': 20,
#  'with': 21,
#  'if': 22,
#  'article': 23,
#  'was': 24,
#  'or': 25,
#  'but': 26,
#  'page': 27,
#  'wikipedia': 28,
#  'my': 29,
#  'an': 30,
#  'from': 31,
#  'by': 32,
#  'do': 33,
#  'at': 34,
#  'me': 35,
#  'about': 36,
#  'so': 37,
#  'talk': 38,
#  'what': 39,
#  'can': 40,
#  'there': 41,
#  'all': 42,
#  'has': 43,
#  'will': 44,
#  'please': 45,
#  'no': 46,
#  'would': 47,
#  'one': 48,
#  'like': 49,
#  'just': 50,
#  'they': 51,
#  'he': 52,
#  'which': 53,
#  'any': 54,
#  'been': 55,
#  'should': 56,
#  'more': 57,
#  'we': 58,
#  "don't": 59,
#  'some': 60,
#  'other': 61,
#  'who': 62,
#  'here': 63,
#  'see': 64,
#  'also': 65,
#  'his': 66,
#  'think': 67,
#  'because': 68,
#  'know': 69,
#  'how': 70,
#  'edit': 71,
#  'am': 72,
#  "i'm": 73,
#  'people': 74,
#  'why': 75,
#  'up': 76,
#  'only': 77,
#  "it's": 78,
#  'out': 79,
#  'articles': 80,
#  'use': 81,
#  'when': 82,
#  'then': 83,
#  'time': 84,
#  'may': 85,
#  'were': 86,
#  'did': 87,
#  'them': 88,
#  'now': 89,
#  'being': 90,
#  'user': 91,
#  'their': 92,
#  'than': 93,
#  'thanks': 94,
#  'even': 95,
#  'get': 96,
#  'make': 97,
#  'good': 98,
#  'had': 99,
#  'well': 100,
#  'very': 101,
#  'information': 102,
#  'does': 103,
#  'could': 104,
#  'want': 105,
#  'deletion': 106,
#  'its': 107,
#  'such': 108,
#  'sources': 109,
#  'way': 110,
#  'name': 111,
#  'these': 112,
#  'first': 113,
#  'wp': 114,
#  'help': 115,
#  'pages': 116,
#  'new': 117,
#  'image': 118,
#  'source': 119,
#  'editing': 120,
#  'go': 121,
#  'need': 122,
#  'section': 123,
#  'say': 124,
#  'again': 125,
#  'edits': 126,
#  'thank': 127,
#  'where': 128,
#  'fuck': 129,
#  'made': 130,
#  'many': 131,
#  'much': 132,
#  'used': 133,
#  'really': 134,
#  'most': 135,
#  'deleted': 136,
#  'discussion': 137,
#  'same': 138,
#  'find': 139,
#  'into': 140,
#  'work': 141,
#  'those': 142,
#  'since': 143,
#  "i've": 144,
#  'right': 145,
#  'point': 146,
#  'before': 147,
#  'after': 148,
#  'add': 149,
#  'read': 150,
#  'look': 151,
#  'over': 152,
#  'him': 153,
#  'take': 154,
#  'two': 155,
#  'still': 156,
#  'back': 157,
#  'wiki': 158,
#  'someone': 159,
#  'fact': 160,
#  'hi': 161,
#  'too': 162,
#  'list': 163,
#  'link': 164,
#  'own': 165,
#  'said': 166,
#  'something': 167,
#  'going': 168,
#  'blocked': 169,
#  '1': 170,
#  '2': 171,
#  'stop': 172,
#  "you're": 173,
#  'content': 174,
#  'without': 175,
#  'block': 176,
#  'under': 177,
#  'history': 178,
#  'http': 179,
#  'our': 180,
#  'added': 181,
#  'utc': 182,
#  'editors': 183,
#  'another': 184,
#  'removed': 185,
#  'her': 186,
#  'might': 187,
#  'welcome': 188,
#  'note': 189,
#  'however': 190,
#  'free': 191,
#  'place': 192,
#  'sure': 193,
#  'case': 194,
#  'never': 195,
#  "doesn't": 196,
#  'done': 197,
#  'us': 198,
#  'vandalism': 199,
#  'reason': 200,
#  'put': 201,
#  'comment': 202,
#  'personal': 203,
#  'better': 204,
#  "that's": 205,
#  'yourself': 206,
#  'using': 207,
#  'seems': 208,
#  'ask': 209,
#  'actually': 210,
#  'question': 211,
#  'off': 212,
#  'while': 213,
#  'feel': 214,
#  'anything': 215,
#  'believe': 216,
#  'links': 217,
#  'person': 218,
#  'things': 219,
#  'both': 220,
#  'she': 221,
#  'best': 222,
#  'comments': 223,
#  'policy': 224,
#  'part': 225,
#  'hope': 226,
#  'against': 227,
#  "can't": 228,
#  'already': 229,
#  'keep': 230,
#  'thing': 231,
#  '3': 232,
#  'u': 233,
#  "didn't": 234,
#  'questions': 235,
#  "i'll": 236,
#  'com': 237,
#  'nothing': 238,
#  'change': 239,
#  'wrong': 240,
#  'though': 241,
#  'subject': 242,
#  'problem': 243,
#  'remove': 244,
#  'little': 245,
#  'copyright': 246,
#  'tag': 247,
#  '•': 248,
#  'trying': 249,
#  'long': 250,
#  'must': 251,
#  'understand': 252,
#  'above': 253,
#  'speedy': 254,
#  'anyone': 255,
#  'few': 256,
#  'world': 257,
#  'issue': 258,
#  'last': 259,
#  'others': 260,
#  'give': 261,
#  'editor': 262,
#  'sorry': 263,
#  'agree': 264,
#  'reliable': 265,
#  'rather': 266,
#  'let': 267,
#  'years': 268,
#  'fair': 269,
#  'english': 270,
#  'different': 271,
#  'making': 272,
#  'reference': 273,
#  'come': 274,
#  'style': 275,
#  'text': 276,
#  'references': 277,
#  'mean': 278,
#  'try': 279,
#  'non': 280,
#  'continue': 281,
#  'doing': 282,
#  'great': 283,
#  'found': 284,
#  'leave': 285,
#  'word': 286,
#  'says': 287,
#  'got': 288,
#  'state': 289,
#  'original': 290,
#  "isn't": 291,
#  'probably': 292,
#  'site': 293,
#  'adding': 294,
#  'every': 295,
#  'check': 296,
#  'day': 297,
#  'simply': 298,
#  'created': 299,
#  'life': 300,
#  'top': 301,
#  'hello': 302,
#  'show': 303,
#  'post': 304,
#  'either': 305,
#  'consensus': 306,
#  'ip': 307,
#  'least': 308,
#  'delete': 309,
#  'else': 310,
#  'e': 311,
#  'yes': 312,
#  'view': 313,
#  'war': 314,
#  'far': 315,
#  'notable': 316,
#  'enough': 317,
#  'request': 318,
#  'etc': 319,
#  'example': 320,
#  'opinion': 321,
#  'contributions': 322,
#  'called': 323,
#  'around': 324,
#  'through': 325,
#  'www': 326,
#  'between': 327,
#  'real': 328,
#  'yet': 329,
#  'write': 330,
#  'reverted': 331,
#  'book': 332,
#  'shit': 333,
#  'down': 334,
#  'matter': 335,
#  'admin': 336,
#  're': 337,
#  'thought': 338,
#  'given': 339,
#  'images': 340,
#  'account': 341,
#  'material': 342,
#  'users': 343,
#  'bad': 344,
#  'encyclopedia': 345,
#  'having': 346,
#  'clearly': 347,
#  'title': 348,
#  'message': 349,
#  'support': 350,
#  'needs': 351,
#  'lot': 352,
#  'old': 353,
#  'evidence': 354,
#  '—': 355,
#  'ever': 356,
#  'maybe': 357,
#  's': 358,
#  'tell': 359,
#  'revert': 360,
#  'seem': 361,
#  'language': 362,
#  'instead': 363,
#  'correct': 364,
#  'template': 365,
#  'org': 366,
#  'number': 367,
#  'clear': 368,
#  'media': 369,
#  'important': 370,
#  'saying': 371,
#  'pov': 372,
#  '5': 373,
#  '4': 374,
#  'always': 375,
#  'written': 376,
#  'true': 377,
#  'oh': 378,
#  'term': 379,
#  'further': 380,
#  'states': 381,
#  'hate': 382,
#  'quite': 383,
#  'perhaps': 384,
#  'review': 385,
#  'until': 386,
#  'bit': 387,
#  'whether': 388,
#  "i'd": 389,
#  'research': 390,
#  'consider': 391,
#  'claim': 392,
#  'guidelines': 393,
#  'fucking': 394,
#  'version': 395,
#  'once': 396,
#  'based': 397,
#  'criteria': 398,
#  'times': 399,
#  'nigger': 400,
#  'website': 401,
#  'getting': 402,
#  'suck': 403,
#  'mention': 404,
#  'three': 405,
#  'several': 406,
#  'makes': 407,
#  'considered': 408,
#  'words': 409,
#  'c': 410,
#  'year': 411,
#  'hey': 412,
#  'changes': 413,
#  'idea': 414,
#  "there's": 415,
#  'cannot': 416,
#  'ass': 417,
#  'address': 418,
#  'notice': 419,
#  'current': 420,
#  'group': 421,
#  'left': 422,
#  'following': 423,
#  'listed': 424,
#  'each': 425,
#  'date': 426,
#  'second': 427,
#  'means': 428,
#  'facts': 429,
#  'rules': 430,
#  'general': 431,
#  'possible': 432,
#  'main': 433,
#  'care': 434,
#  'regarding': 435,
#  'american': 436,
#  'man': 437,
#  'start': 438,
#  '10': 439,
#  'topic': 440,
#  'mentioned': 441,
#  'course': 442,
#  'attack': 443,
#  'kind': 444,
#  'whole': 445,
#  'statement': 446,
#  'known': 447,
#  'end': 448,
#  'include': 449,
#  'issues': 450,
#  'seen': 451,
#  'create': 452,
#  'jpg': 453,
#  'dont': 454,
#  'en': 455,
#  'gay': 456,
#  'less': 457,
#  'related': 458,
#  'call': 459,
#  'ok': 460,
#  'sense': 461,
#  'big': 462,
#  'suggest': 463,
#  'happy': 464,
#  'category': 465,
#  'including': 466,
#  'notability': 467,
#  'info': 468,
#  '2005': 469,
#  'provide': 470,
#  'redirect': 471,
#  'days': 472,
#  'move': 473,
#  'myself': 474,
#  'sentence': 475,
#  "wikipedia's": 476,
#  'love': 477,
#  'four': 478,
#  'appropriate': 479,
#  'school': 480,
#  'news': 481,
#  'project': 482,
#  'changed': 483,
#  'explain': 484,
#  'started': 485,
#  'neutral': 486,
#  'line': 487,
#  'mind': 488,
#  'anyway': 489,
#  'contribs': 490,
#  'included': 491,
#  'removing': 492,
#  'next': 493,
#  't': 494,
#  'looking': 495,
#  'picture': 496,
#  'specific': 497,
#  'community': 498,
#  'although': 499,
#  'per': 500,
#  'order': 501,
#  'relevant': 502,
#  'sign': 503,
#  'die': 504,
#  'answer': 505,
#  'away': 506,
#  'interest': 507,
#  'full': 508,
#  'warning': 509,
#  'lol': 510,
#  'summary': 511,
#  'recent': 512,
#  'later': 513,
#  'file': 514,
#  'policies': 515,
#  "you've": 516,
#  'faith': 517,
#  'claims': 518,
#  'discuss': 519,
#  'attacks': 520,
#  'public': 521,
#  '0': 522,
#  'currently': 523,
#  'wrote': 524,
#  'writing': 525,
#  'especially': 526,
#  'interested': 527,
#  'able': 528,
#  'wish': 529,
#  'taken': 530,
#  '6': 531,
#  'names': 532,
#  'position': 533,
#  'single': 534,
#  'within': 535,
#  'stuff': 536,
#  'below': 537,
#  '2006': 538,
#  'during': 539,
#  'wanted': 540,
#  'web': 541,
#  'appears': 542,
#  'official': 543,
#  '20': 544,
#  'live': 545,
#  'certainly': 546,
#  'nice': 547,
#  'color': 548,
#  'self': 549,
#  'itself': 550,
#  'country': 551,
#  'everyone': 552,
#  'report': 553,
#  'anti': 554,
#  'background': 555,
#  'lead': 556,
#  'high': 557,
#  'common': 558,
#  'god': 559,
#  'unless': 560,
#  'according': 561,
#  'completely': 562,
#  'hard': 563,
#  'books': 564,
#  'pretty': 565,
#  '7': 566,
#  'everything': 567,
#  'p': 568,
#  'published': 569,
#  'due': 570,
#  '24': 571,
#  'process': 572,
#  'edited': 573,
#  'looks': 574,
#  'involved': 575,
#  'fat': 576,
#  'therefore': 577,
#  "won't": 578,
#  'remember': 579,
#  'obviously': 580,
#  'power': 581,
#  'd': 582,
#  'future': 583,
#  'nor': 584,
#  '100': 585,
#  'truth': 586,
#  'came': 587,
#  'sandbox': 588,
#  '11': 589,
#  'response': 590,
#  'party': 591,
#  'reading': 592,
#  'stay': 593,
#  'past': 594,
#  'game': 595,
#  'learn': 596,
#  'admins': 597,
#  'quote': 598,
#  'asked': 599,
#  "wasn't": 600,
#  'b': 601,
#  'city': 602,
#  'entry': 603,
#  'stupid': 604,
#  "he's": 605,
#  'posted': 606,
#  'false': 607,
#  'faggot': 608,
#  'whatever': 609,
#  'google': 610,
#  'talking': 611,
#  'ago': 612,
#  '8': 613,
#  'placed': 614,
#  'political': 615,
#  'similar': 616,
#  'today': 617,
#  'system': 618,
#  'administrator': 619,
#  'united': 620,
#  'argument': 621,
#  'paragraph': 622,
#  'working': 623,
#  'exactly': 624,
#  '2007': 625,
#  'guy': 626,
#  '12': 627,
#  'british': 628,
#  'took': 629,
#  'useful': 630,
#  'government': 631,
#  'search': 632,
#  'noticed': 633,
#  'moron': 634,
#  'regards': 635,
#  'small': 636,
#  'reasons': 637,
#  'side': 638,
#  '2008': 639,
#  'form': 640,
#  'national': 641,
#  'dispute': 642,
#  'deleting': 643,
#  'five': 644,
#  'guess': 645,
#  'appreciate': 646,
#  'particular': 647,
#  'reverting': 648,
#  'major': 649,
#  'problems': 650,
#  'law': 651,
#  '000': 652,
#  '15': 653,
#  'npov': 654,
#  'bitch': 655,
#  'rule': 656,
#  'banned': 657,
#  'often': 658,
#  'provided': 659,
#  'music': 660,
#  'become': 661,
#  'wikiproject': 662,
#  'needed': 663,
#  'status': 664,
#  'reply': 665,
#  'knowledge': 666,
#  'tried': 667,
#  'along': 668,
#  'almost': 669,
#  'cheers': 670,
#  'stated': 671,
#  'username': 672,
#  'film': 673,
#  '9': 674,
#  'taking': 675,
#  'fine': 676,
#  '–': 677,
#  'company': 678,
#  'vandalize': 679,
#  'present': 680,
#  'certain': 681,
#  'white': 682,
#  'follow': 683,
#  'sort': 684,
#  'otherwise': 685,
#  'terms': 686,
#  'points': 687,
#  'explanation': 688,
#  'uploaded': 689,
#  "haven't": 690,
#  'description': 691,
#  'generally': 692,
#  'recently': 693,
#  'entire': 694,
#  'open': 695,
#  'story': 696,
#  'tags': 697,
#  'shows': 698,
#  'alone': 699,
#  'ban': 700,
#  'citation': 701,
#  'short': 702,
#  'definition': 703,
#  '14': 704,
#  'cited': 705,
#  'likely': 706,
#  'aware': 707,
#  'g': 708,
#  'saw': 709,
#  'class': 710,
#  'type': 711,
#  'soon': 712,
#  'set': 713,
#  'week': 714,
#  'indeed': 715,
#  'band': 716,
#  'cite': 717,
#  'decide': 718,
#  'mr': 719,
#  'views': 720,
#  '2004': 721,
#  'appear': 722,
#  'family': 723,
#  'simple': 724,
#  'area': 725,
#  'guys': 726,
#  'theory': 727,
#  'piece': 728,
#  'contributing': 729,
#  'contact': 730,
#  'external': 731,
#  'result': 732,
#  'test': 733,
#  'internet': 734,
#  'interesting': 735,
#  'unblock': 736,
#  'actual': 737,
#  'improve': 738,
#  'copy': 739,
#  '16': 740,
#  'sourced': 741,
#  'jew': 742,
#  'told': 743,
#  'attention': 744,
#  'proposed': 745,
#  'obvious': 746,
#  'moved': 747,
#  'email': 748,
#  'uk': 749,
#  'members': 750,
#  'various': 751,
#  'allowed': 752,
#  'themselves': 753,
#  'conflict': 754,
#  'context': 755,
#  "article's": 756,
#  'black': 757,
#  'university': 758,
#  'author': 759,
#  'thus': 760,
#  'disagree': 761,
#  'cunt': 762,
#  'john': 763,
#  'went': 764,
#  'citations': 765,
#  'sites': 766,
#  'jews': 767,
#  'actions': 768,
#  'hand': 769,
#  'bias': 770,
#  'previous': 771,
#  'third': 772,
#  'hours': 773,
#  'human': 774,
#  '18': 775,
#  'works': 776,
#  'nonsense': 777,
#  'science': 778,
#  'ones': 779,
#  'death': 780,
#  'action': 781,
#  '17': 782,
#  'enjoy': 783,
#  "aren't": 784,
#  'job': 785,
#  'proper': 786,
#  'longer': 787,
#  'large': 788,
#  'together': 789,
#  'sucks': 790,
#  '\xa0': 791,
#  '13': 792,
#  'addition': 793,
#  "wouldn't": 794,
#  'avoid': 795,
#  'creating': 796,
#  'happened': 797,
#  '19': 798,
#  'valid': 799,
#  'jewish': 800,
#  'german': 801,
#  'deal': 802,
#  '21': 803,
#  'automatically': 804,
#  'biased': 805,
#  'proof': 806,
#  'worked': 807,
#  'im': 808,
#  'series': 809,
#  'dick': 810,
#  'goes': 811,
#  'himself': 812,
#  'seriously': 813,
#  "what's": 814,
#  '23': 815,
#  'level': 816,
#  'standard': 817,
#  'f': 818,
#  '2009': 819,
#  'accepted': 820,
#  'respect': 821,
#  'exist': 822,
#  'available': 823,
#  'de': 824,
#  'helpful': 825,
#  'video': 826,
#  'comes': 827,
#  '22': 828,
#  'meaning': 829,
#  "shouldn't": 830,
#  'manual': 831,
#  'living': 832,
#  'opinions': 833,
#  'sex': 834,
#  'rights': 835,
#  'act': 836,
#  'tildes': 837,
#  'criticism': 838,
#  'play': 839,
#  '2010': 840,
#  'necessary': 841,
#  'calling': 842,
#  'accept': 843,
#  'sections': 844,
#  'indicate': 845,
#  'personally': 846,
#  'yeah': 847,
#  '30': 848,
#  'july': 849,
#  'hell': 850,
#  'accurate': 851,
#  'violation': 852,
#  'statements': 853,
#  'pig': 854,
#  'attempt': 855,
#  'months': 856,
#  'assume': 857,
#  'afd': 858,
#  'upon': 859,
#  'historical': 860,
#  'usually': 861,
#  'debate': 862,
#  "let's": 863,
#  'pro': 864,
#  'details': 865,
#  'multiple': 866,
#  'blocking': 867,
#  'south': 868,
#  'rest': 869,
#  'tagged': 870,
#  'width': 871,
#  'serious': 872,
#  'doubt': 873,
#  'record': 874,
#  'greek': 875,
#  'm': 876,
#  'r': 877,
#  "they're": 878,
#  'separate': 879,
#  'v': 880,
#  'space': 881,
#  'situation': 882,
#  'cause': 883,
#  "you'll": 884,
#  'speak': 885,
#  'heard': 886,
#  'explaining': 887,
#  'okay': 888,
#  'refer': 889,
#  'fix': 890,
#  'run': 891,
#  'quality': 892,
#  'data': 893,
#  'complete': 894,
#  'penis': 895,
#  'sock': 896,
#  'church': 897,
#  'w': 898,
#  'messages': 899,
#  'none': 900,
#  'india': 901,
#  'asking': 902,
#  'august': 903,
#  'online': 904,
#  'lack': 905,
#  'legal': 906,
#  'period': 907,
#  'freedom': 908,
#  'team': 909,
#  'military': 910,
#  'rationale': 911,
#  'behavior': 912,
#  'prove': 913,
#  'apparently': 914,
#  'access': 915,
#  'special': 916,
#  'close': 917,
#  'changing': 918,
#  'bullshit': 919,
#  'directly': 920,
#  'watch': 921,
#  'culture': 922,
#  'difference': 923,
#  'march': 924,
#  'early': 925,
#  'box': 926,
#  'contribute': 927,
#  'wikipedian': 928,
#  'existing': 929,
#  'huge': 930,
#  'gets': 931,
#  'html': 932,
#  'couple': 933,
#  '25': 934,
#  'among': 935,
#  'civil': 936,
#  'warring': 937,
#  'supposed': 938,
#  'primary': 939,
#  'except': 940,
#  'head': 941,
#  'countries': 942,
#  'born': 943,
#  'meant': 944,
#  'modern': 945,
#  '50': 946,
#  'photo': 947,
#  'described': 948,
#  'incorrect': 949,
#  'fish': 950,
#  'uses': 951,
#  'disruptive': 952,
#  'significant': 953,
#  'field': 954,
#  'specifically': 955,
#  'red': 956,
#  'purpose': 957,
#  'pillars': 958,
#  'friend': 959,
#  'release': 960,
#  'archive': 961,
#  'million': 962,
#  'produce': 963,
#  'tv': 964,
#  'error': 965,
#  'force': 966,
#  'table': 967,
#  'earlier': 968,
#  'business': 969,
#  'computer': 970,
#  'june': 971,
#  'sometimes': 972,
#  'half': 973,
#  'cases': 974,
#  'outside': 975,
#  'vote': 976,
#  'x': 977,
#  'inclusion': 978,
#  'particularly': 979,
#  'character': 980,
#  'pictures': 981,
#  'gave': 982,
#  'linked': 983,
#  'abuse': 984,
#  '27': 985,
#  'control': 986,
#  'possibly': 987,
#  'numbers': 988,
#  'home': 989,
#  'anonymous': 990,
#  'member': 991,
#  'january': 992,
#  'christian': 993,
#  'scientific': 994,
#  'arguments': 995,
#  'tutorial': 996,
#  '2012': 997,
#  'n': 998,
#  'reported': 999,
#  'border': 1000,
#  ...}

# %% [markdown]
# Simple bidirectional LSTM with two fully connected layers. We add some dropout to the LSTM since even 2 epochs is enough to overfit.

# %%
inp = Input(shape=(maxlen,))
x = Embedding(max_features, embed_size, weights=[embedding_matrix])(inp)
x = Bidirectional(LSTM(50, return_sequences=True, dropout=0.1, recurrent_dropout=0.1))(x)
x = GlobalMaxPool1D()(x)
x = Dense(50, activation="relu")(x)
x = Dropout(0.1)(x)
x = Dense(6, activation="sigmoid")(x)
model = Model(inputs=inp, outputs=x)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Now we're ready to fit out model! Use `validation_split` when not submitting.

# %%
model.fit(X_t, y, batch_size=64, epochs=3) # validation_split=0.1);
# Out:
# Epoch 1/3
# 159571/159571 [==============================] - 169s 1ms/step - loss: 0.0702 - acc: 0.9776
# Epoch 2/3
# 159571/159571 [==============================] - 170s 1ms/step - loss: 0.0527 - acc: 0.9814
# Epoch 3/3
# 159571/159571 [==============================] - 160s 1ms/step - loss: 0.0480 - acc: 0.9826

# %%
model.fit(X_t, y, batch_size=128, epochs=1) # validation_split=0.1);
# Out:
# Epoch 1/1
# 159571/159571 [==============================] - 81s 506us/step - loss: 0.0440 - acc: 0.9835

# %% [markdown]
# And finally, get predictions for the test set and prepare a submission CSV:

# %%
y_test = model.predict([X_te], batch_size=1024, verbose=1)
sample_submission = pd.read_csv(f'{path}{comp}sample_submission.csv')
sample_submission[list_classes] = y_test
sample_submission.to_csv('submission_glove.csv', index=False)
# Out:
# 153164/153164 [==============================] - 4s 26us/step
